# %% [markdown]
# <a href="https://colab.research.google.com/github/SDlel/ml-assignments/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SDlel/ml-assignments/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# I chose the Refresh / Content Opportunity Scoring lane. I would frame this as a classification task because the goal is to predict whether a content page is likely to be a strong candidate for review based on its search and engagement signals. The predicted probabilities can then be used to rank pages so reviewers can focus on the ones most likely to need attention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !git clone https://github.com/SDlel/ml-assignments.git
# %cd ml-assignments
# Out:
# Cloning into 'ml-assignments'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 124 (delta 40), reused 92 (delta 29), pack-reused 0 (from 0)
# Receiving objects: 100% (124/124), 1.85 MiB | 12.60 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# /content/ml-assignments/ml-assignments

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# The target I would predict is whether a content page should be considered a review candidate. For this assignment, I will use the starter dataset's decline label as a proxy, where pages with a trend direction of "down" are treated as positive examples. This is a defined rule rather than a true future outcome, so it should be viewed as a starting point for learning rather than the final target for the project.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
# I will use Precision@50 as my main success metric because the goal is to help reviewers decide which pages to look at first. A higher Precision@50 means that more of the top 50 recommended pages are actually good candidates for review. This metric matches the real workflow better than overall accuracy because reviewers only have time to investigate a limited number of pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
# The unit of analysis is one content page. Each row in the dataframe represents a single content page with its search performance, engagement metrics, and content characteristics. These features are used to estimate whether the page should be reviewed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("One row represents one content page.")
print("Shape:", df.shape)

df.head()
# Out:
# One row represents one content page.
# Shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
# A fixed rule can only check a few conditions at a time, such as whether a page has low CTR or declining traffic. Machine learning can combine many different signals, including impressions, clicks, engagement, content age, and average position, to find patterns that are difficult to capture with simple if statements. The goal is not to replace human judgment, but to produce a better ranked list of pages for review based on the available evidence.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
